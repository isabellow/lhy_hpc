# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
'''
sanity check/basic behavioral analysis of a given session

bottom camera things:
- initially, label checks/caches/retrievals using correlation as in Applegate et al
    --> later, use behavior to track more precisely (SC method..)
- checks per min
- caches per min
- retrievals per min
- cumulative caches over time
- cumulative retrievals over time
- N seeds cached over time

longer term multi-camera:
- position over time
- movement speed
'''
# define paths
data_root = "Z:/Isabel/data/behavior/"
bird_id = "SPP46"
session_id = "230407"
data_dir = f"{data_root}/{bird_id}/{bird_id}_{session_id}/"

# %%
# load bottom camera video
